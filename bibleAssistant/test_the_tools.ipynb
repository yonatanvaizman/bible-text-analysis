# %% [markdown]
# # Test the tools (directly, without and agent)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path
current_dir = Path().resolve()
sys.path.append(str(current_dir.parent))

# %%
import bibleAssistant.bible_tools as bblt

# %%
response = bblt.search_phrase("ערום")

# %%
response.json()
# Out:
# {'results': [{'pk': 1132418,
#    'translation': 'WLCC',
#    'book': 1,
#    'chapter': 3,
#    'verse': 1,
#    'text': 'והנחש היה <mark>ערום</mark> מכל חית השדה אשר עשה יהוה אלהים ויאמר אל־האשה אף כי־אמר אלהים לא תאכלו מכל עץ הגן׃'},
#   {'pk': 1138138,
#    'translation': 'WLCC',
#    'book': 5,
#    'chapter': 32,
#    'verse': 17,
#    'text': 'יזבחו לשדים לא אלה אלהים לא ידעום חדשים מקרב באו לא ש<mark>ערום</mark> אבתיכם׃'},
#   {'pk': 1140196,
#    'translation': 'WLCC',
#    'book': 9,
#    'chapter': 23,
#    'verse': 22,
#    'text': 'לכו־נא הכינו עוד ודעו וראו את־מקומו אשר תהיה רגלו מי ראהו שם כי אמר אלי <mark>ערום</mark> יערם הוא׃'},
#   {'pk': 1145808,
#    'translation': 'WLCC',
#    'book': 18,
#    'chapter': 24,
#    'verse': 7,
#    'text': '<mark>ערום</mark> ילינו מבלי לבוש ואין כסות בקרה׃'},
#   {'pk': 1145811,
#    'translation': 'WLCC',
#    'book': 18,
#    'chapter': 24,
#    'verse': 10,
#    'text': '<mark>ערום</mark> הלכו בלי לבוש ורעבים נשאו עמר׃'},
#   {'pk': 1145838,
#    'translation': 'WLCC',
#    'book': 18,
#    'chapter': 26,
#    'verse': 6,
#    'text': '<mark>ערום</mark> שאול נגדו ואין כסות לאבדון׃'},
#   {'pk': 1149166,
#    'translation': 'WLCC',
#    'book': 20,
#    'chapter': 12,
#    'verse': 16,
#    'text': 'אויל ביום יודע כעסו וכסה קלון <mark>ערום</mark>׃'},
#   {'pk': 1149173,
#    'translation': 'WLCC',
#    'book': 20,
#    'chapter': 12,
#    'verse': 23,
#    'text': 'אדם <mark>ערום</mark> כסה דעת ולב כסילים יקרא אולת׃'},
#   {'pk': 1149194,
#    'translation': 'WLCC',
#    'book': 20,
#    'chapter': 13,
#    'verse': 16,
#    'text': 'כל־<mark>ערום</mark> יעשה בדעת וכסיל יפרש אולת׃'},
#   {'pk': 1149211,
#    'translation': 'WLCC',
#    'book': 20,
#    'chapter': 14,
#    'verse': 8,
#    'text': 'חכמת <mark>ערום</mark> הבין דרכו ואולת כסילים מרמה׃'},
#   {'pk': 1149218,
#    'translation': 'WLCC',
#    'book': 20,
#    'chapter': 14,
#    'verse': 15,
#    'text': 'פתי יאמין לכל־דבר ו<mark>ערום</mark> יבין לאשרו׃'},
#   {'pk': 1149449,
#    'translation': 'WLCC',
#    'book': 20,
#    'chapter': 22,
#    'verse': 3,
#    'text': '<mark>ערום</mark> ׀ ראה רעה [ויסתר כ] (ונסתר ק) ופתיים עברו ונענשו׃'},
#   {'pk': 1149612,
#    'translation': 'WLCC',
#    'book': 20,
#    'chapter': 27,
#    'verse': 12,
#    'text': '<mark>ערום</mark> ראה רעה נסתר פתאים עברו נענשו׃'},
#   {'pk': 1149843,
#    'translation': 'WLCC',
#    'book': 21,
#    'chapter': 5,
#    'verse': 14,
#    'text': 'כאשר יצא מבטן אמו <mark>ערום</mark> ישוב ללכת כשבא ומאומה לא־ישא בעמלו שילך בידו׃'},
#   {'pk': 1150462,
#    'translation': 'WLCC',
#    'book': 23,
#    'chapter': 20,
#    'verse': 2,
#    'text': 'בעת ההיא דבר יהוה ביד ישעיהו בן־אמוץ לאמר לך ופתחת השק מעל מתניך ונעלך תחלץ מעל רגליך ויעש כן הלך <mark>ערום</mark> ויחף׃    ס'},
#   {'pk': 1150463,
#    'translation': 'WLCC',
#    'book': 23,
#    'chapter': 20,
#    'verse': 3,
#    'text': 'ויאמר יהוה כאשר הלך עבדי ישעיהו <mark>ערום</mark> ויחף שלש שנים אות ומופת על־מצרים ועל־כוש׃'},
#   {'pk': 1150464,
#    'translation': 'WLCC',
#    'book': 23,
#    'chapter': 20,
#    'verse': 4,
#    'text': 'כן ינהג מלך־אשור את־שבי מצרים ואת־גלות כוש נערים וזקנים <mark>ערום</mark> ויחף וחשופי שת ערות מצרים׃'},
#   {'pk': 1153295,
#    'translation': 'WLCC',
#    'book': 26,
#    'chapter': 18,
#    'verse': 16,
#    'text': 'ואיש לא הונה חבל לא חבל וגזלה לא גזל לחמו לרעב נתן ו<mark>ערום</mark> כסה־בגד׃'},
#   {'pk': 1154825,
#    'translation': 'WLCC',
#    'book': 30,
#    'chapter': 2,
#    'verse': 16,
#    'text': 'ואמיץ לבו בגבורים <mark>ערום</mark> ינוס ביום־ההוא נאם־יהוה׃  פ'},
#   {'pk': 1155017,
#    'translation': 'WLCC',
#    'book': 33,
#    'chapter': 1,
#    'verse': 8,
#    'text': 'על־זאת אספדה ואילילה אילכה [שילל כ] (שולל ק) ו<mark>ערום</mark> אעשה מספד כתנים ואבל כבנות יענה׃'}],
#  'exact_matches': 20,
#  'total': 20}
