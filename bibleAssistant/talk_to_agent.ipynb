# %% [markdown]
# # Tals to the AI Assistant
#
# * Use the Bible Assistant
# * Test how helpful it is
# * See how to improve it next

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path

current_dir = Path().resolve()

#sys.path.append(str(current_dir))
sys.path.append(str(current_dir.parent))

# %%
import bibleAssistant.agent
#model_name = "gemma3:1b"
#model_name = "llama3.2:3b"
#model_name = "gemma3:4b"
#model_name = "mistral:latest"
#model_name = "gemma3:1b-ft1"
model_name = "gemma3:1b-ft3-50"
agentUI = bibleAssistant.agent.AgentUI(model_name, verbose=False)
#agentUI.agent.llm_response_schema

# %%
agentUI.start_session()
# Out:
# Agent ready to talk. Type 'exit' to quit.
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# hello</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# hello</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# please show me a verse from teh book of isaiah, chapter 10 verse 3, from version 'he.masorah'</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# וּמַֽה־תַּעֲשׂוּ֙ לְי֣וֹם פְּקֻדָּ֔ה וּלְשׁוֹאָ֖ה מִמֶּרְחָ֣ק תָּב֑וֹא עַל־מִי֙ תָּנ֣וּסוּ לְעֶזְרָ֔ה וְאָ֥נָה תַעַזְב֖וּ כְּבוֹדְכֶֽם׃</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# please fetch teh same verse (isaiah, 10:3) from a different version 'he.text_only'</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# ומה תעשו ליום פקדה ולשואה ממרחק תבוא על מי תנוסו לעזרה ואנה תעזבו כבודכם</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# great. and now the same verse (isaiah 10:3) from version 'en.koren'</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# And what will you do in the day of visitation, and in the desolation which shall come from far? to whom will you flee for help? and where will you leave your glory?</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# exit</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# Bye!</div>

# %%
print("="*40)
for msg in agentUI.agent.messages:
    print(msg)
#    print(f"{msg['role']}: {msg['content']}")
print("="*40)
# Out:
# ========================================
# {'role': 'system', 'content': 'You are a research assistant that always responds using a JSON object with fields "tool" and "arguments".\n\nTo respond normally to the user, use:\n{"tool": "respond_to_user", "arguments":{"text": "<text to show the user>"}}\n\nTo call a tool, use:\n{"tool": "<tool_name>", "arguments":{ ... }}\n\nAfter you call a tool, you will receive a message with role "user" containing a JSON object.\nThe tool message always includes "tool_name" and "status".\n\nIf "status" is "ok":\n- The message will include a "result" object.\n- Read "result.text".\n- Respond using "respond_to_user" and copy "result.text" exactly as-is.\n\nIf "status" is "error":\n- The message will include an "error_message".\n- If the error message is clear enough (e.g., if the user spelled a book name wrong and it is clear which book the user intended), you can call the tool again with the corrected arguments.\n- Otherwise, respond using "respond_to_user" and copy "error_message" exactly as-is (to let the user tell you what to do next).\n\nRules:\n- Never modify, translate, summarize, or explain text returned by the tool.\n- Never add commentary or extra text.\n- Never guess missing arguments.\n- Never correct user mistakes on the first attempt of a tool call.\n- Never retry a failed tool call with exactly the same arguments.\n\nAvailable tool:\n\nTo get the text of a specific biblical verse:\n{"tool": "lookup_verse", "arguments":{"version":"<version>", book:"<book>", chapter_num:<integer>, verse_num:<integer>}}\nWhen this tool call succeeds, contains the verse. Copy it exactly as-is and return to the user with "respond_to_user".\n\n'}
# {'role': 'user', 'content': 'hello'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments":{"text": "hello"}}'}
# {'role': 'user', 'content': "please show me a verse from teh book of isaiah, chapter 10 verse 3, from version 'he.masorah'"}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments":{"version":"he.masorah", "book":"isaiah", "chapter_num":10, "verse_num":3}}\n'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "ok", "result": {"version": "he.masorah", "book": "isaiah", "chapter_num": 10, "verse_num": 3, "text": "וּמַֽה־תַּעֲשׂוּ֙ לְי֣וֹם פְּקֻדָּ֔ה וּלְשׁוֹאָ֖ה מִמֶּרְחָ֣ק תָּב֑וֹא עַל־מִי֙ תָּנ֣וּסוּ לְעֶזְרָ֔ה וְאָ֥נָה תַעַזְב֖וּ כְּבוֹדְכֶֽם׃"}}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments":{"text": "וּמַֽה־תַּעֲשׂוּ֙ לְי֣וֹם פְּקֻדָּ֔ה וּלְשׁוֹאָ֖ה מִמֶּרְחָ֣ק תָּב֑וֹא עַל־מִי֙ תָּנ֣וּסוּ לְעֶזְרָ֔ה וְאָ֥נָה תַעַזְב֖וּ כְּבוֹדְכֶֽם׃"}}'}
# {'role': 'user', 'content': "please fetch teh same verse (isaiah, 10:3) from a different version 'he.text_only'"}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments":{"version":"he.text_only", "book":"isaiah", "chapter_num":10, "verse_num":3}}\n'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "ok", "result": {"version": "he.text_only", "book": "isaiah", "chapter_num": 10, "verse_num": 3, "text": "ומה תעשו ליום פקדה ולשואה ממרחק תבוא על מי תנוסו לעזרה ואנה תעזבו כבודכם"}}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments":{"text": "ומה תעשו ליום פקדה ולשואה ממרחק תבוא על מי תנוסו לעזרה ואנה תעזבו כבודכם"}}'}
# {'role': 'user', 'content': "great. and now the same verse (isaiah 10:3) from version 'en.koren'"}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments":{"version":"en.koren", "book":"isaiah", "chapter_num":10, "verse_num":3}}\n'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "ok", "result": {"version": "en.koren", "book": "isaiah", "chapter_num": 10, "verse_num": 3, "text": "And what will you do in the day of visitation, and in the desolation which shall come from far? to whom will you flee for help? and where will you leave your glory?"}}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments":{"text": "And what will you do in the day of visitation, and in the desolation which shall come from far? to whom will you flee for help? and where will you leave your glory?"}}'}
# ========================================
