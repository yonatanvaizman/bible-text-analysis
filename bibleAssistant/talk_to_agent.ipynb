# %% [markdown]
# # Talk to the AI Assistant
#
# * Use the Bible Assistant
# * Test how helpful it is
# * See how to improve it next

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path
current_dir = Path().resolve()
sys.path.append(str(current_dir.parent))
import bibleAssistant.agent

# %%
model_name = "gemma3:1b-ft9-350"
agentUI = bibleAssistant.agent.AgentUI(model_name, verbose=True)
agentUI.start_session()
# Out:
# ====
# System prompt:
# You are a research assistant that always responds using a JSON object with fields "tool" and "arguments".
#
# To respond normally to the user, use:
# {"tool": "respond_to_user", "arguments":{"text": "<text to show the user>"}}
#
# To call a tool, use:
# {"tool": "<tool_name>", "arguments":{ ... }}
#
# After you call a tool, you will receive a message with role "user" containing a JSON object.
# The tool message always includes "tool_name" and "status".
#
# If "status" is "ok":
# - The message will include a "result" object.
# - Read "result.text".
# - Respond using "respond_to_user" and copy "result.text" exactly as-is.
#
# If "status" is "error":
# - The message will include an "error_message".
# - If the error message is clear enough (e.g., if the user spelled a book name wrong and it is clear which book the user intended), you can call the tool again with the corrected arguments.
# - Otherwise, respond using "respond_to_user" and copy "error_message" exactly as-is (to let the user tell you what to do next).
#
# Rules:
# - Never modify, translate, summarize, or explain text returned by the tool.
# - Never add commentary or extra text.
# - Never guess missing arguments.
# - Never correct user mistakes on the first attempt of a tool call.
# - Never retry a failed tool call with exactly the same arguments.
#
# Available toos:
#
# To get the text of a specific biblical verse:
# {"tool": "lookup_verse", "arguments":{"version":"<version>", book:"<book>", chapter_num:<integer>, verse_num:<integer>}}
# When this tool call succeeds, contains the verse. Copy it exactly as-is and return to the user with "respond_to_user".
#
# To search for all the verses that have a certain word or phrase:
# {"tool": "search_phrase", "arguments":{"phrase":"<phrase>"}}
# When this tool call succeeds, the tool's response will be a dictionary with key "results", holding the list of all the occurrences of the phrase.
# If the user already told you what to do with these result, go ahead and do it. Otherwise respond to the user with "o.k. now what?" to get further instructions.
#
# ====
# LLM response schema:
# {'oneOf': [{'type': 'object', 'properties': {'tool': {'type': 'string', 'enum': ['respond_to_user']}, 'arguments': {'type': 'object', 'properties': {'text': {'type': 'string'}}, 'required': ['text'], 'additionalProperties': False}}, 'required': ['tool', 'arguments'], 'additionalProperties': False}, {'type': 'object', 'properties': {'tool': {'type': 'string', 'enum': ['lookup_verse']}, 'arguments': {'type': 'object', 'properties': {'version': {'type': 'string'}, 'book': {'type': 'string'}, 'chapter_num': {'type': 'integer'}, 'verse_num': {'type': 'integer'}}, 'required': ['version', 'book', 'chapter_num', 'verse_num'], 'additionalProperties': False}}, 'required': ['tool', 'arguments'], 'additionalProperties': False}, {'type': 'object', 'properties': {'tool': {'type': 'string', 'enum': ['search_phrase']}, 'arguments': {'type': 'object', 'properties': {'phrase': {'type': 'string'}}, 'required': ['phrase'], 'additionalProperties': False}}, 'required': ['tool', 'arguments'], 'additionalProperties': False}]}
# ====
# Agent ready to talk. Type 'exit' to quit.
# <div style='display: inline-block; border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'><span style='color: #9944FF'>You:</span><br/>search for all the verses that contain the phrase "ערום"</div>
# {'role': 'user', 'content': 'search for all the verses that contain the phrase "ערום"'}
# {'role': 'assistant', 'content': '{"tool": "search_phrase", "arguments": {"phrase": "ערום"}}\n'}
# {'role': 'user', 'content': '{"tool_name": "search_phrase", "status": "ok", "result": {"results": [{"book_id": 1, "book_name": "Genesis", "chapter": 3, "verse": 1, "text": "והנחש היה ערום מכל חית השדה אשר עשה יהוה אלהים ויאמר אל־האשה אף כי־אמר אלהים לא תאכלו מכל עץ הגן׃"}, {"book_id": 5, "book_name": "Deuteronomy", "chapter": 32, "verse": 17, "text": "יזבחו לשדים לא אלה אלהים לא ידעום חדשים מקרב באו לא שערום אבתיכם׃"}, {"book_id": 9, "book_name": "1 Samuel", "chapter": 23, "verse": 22, "text": "לכו־נא הכינו עוד ודעו וראו את־מקומו אשר תהיה רגלו מי ראהו שם כי אמר אלי ערום יערם הוא׃"}, {"book_id": 18, "book_name": "Job", "chapter": 24, "verse": 7, "text": "ערום ילינו מבלי לבוש ואין כסות בקרה׃"}, {"book_id": 18, "book_name": "Job", "chapter": 24, "verse": 10, "text": "ערום הלכו בלי לבוש ורעבים נשאו עמר׃"}, {"book_id": 18, "book_name": "Job", "chapter": 26, "verse": 6, "text": "ערום שאול נגדו ואין כסות לאבדון׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 12, "verse": 16, "text": "אויל ביום יודע כעסו וכסה קלון ערום׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 12, "verse": 23, "text": "אדם ערום כסה דעת ולב כסילים יקרא אולת׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 13, "verse": 16, "text": "כל־ערום יעשה בדעת וכסיל יפרש אולת׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 14, "verse": 8, "text": "חכמת ערום הבין דרכו ואולת כסילים מרמה׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 14, "verse": 15, "text": "פתי יאמין לכל־דבר וערום יבין לאשרו׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 22, "verse": 3, "text": "ערום ׀ ראה רעה [ויסתר כ] (ונסתר ק) ופתיים עברו ונענשו׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 27, "verse": 12, "text": "ערום ראה רעה נסתר פתאים עברו נענשו׃"}, {"book_id": 21, "book_name": "Ecclesiastes", "chapter": 5, "verse": 14, "text": "כאשר יצא מבטן אמו ערום ישוב ללכת כשבא ומאומה לא־ישא בעמלו שילך בידו׃"}, {"book_id": 23, "book_name": "Isaiah", "chapter": 20, "verse": 2, "text": "בעת ההיא דבר יהוה ביד ישעיהו בן־אמוץ לאמר לך ופתחת השק מעל מתניך ונעלך תחלץ מעל רגליך ויעש כן הלך ערום ויחף׃    ס"}, {"book_id": 23, "book_name": "Isaiah", "chapter": 20, "verse": 3, "text": "ויאמר יהוה כאשר הלך עבדי ישעיהו ערום ויחף שלש שנים אות ומופת על־מצרים ועל־כוש׃"}, {"book_id": 23, "book_name": "Isaiah", "chapter": 20, "verse": 4, "text": "כן ינהג מלך־אשור את־שבי מצרים ואת־גלות כוש נערים וזקנים ערום ויחף וחשופי שת ערות מצרים׃"}, {"book_id": 26, "book_name": "Ezekiel", "chapter": 18, "verse": 16, "text": "ואיש לא הונה חבל לא חבל וגזלה לא גזל לחמו לרעב נתן וערום כסה־בגד׃"}, {"book_id": 30, "book_name": "Amos", "chapter": 2, "verse": 16, "text": "ואמיץ לבו בגבורים ערום ינוס ביום־ההוא נאם־יהוה׃  פ"}, {"book_id": 33, "book_name": "Micah", "chapter": 1, "verse": 8, "text": "על־זאת אספדה ואילילה אילכה [שילל כ] (שולל ק) וערום אעשה מספד כתנים ואבל כבנות יענה׃"}]}}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "o.k. now what?"}}'}
# <div style='display: inline-block; border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'><span style='color: #2222FF'>Assistant:</span><br/>o.k. now what?</div>
# <div style='display: inline-block; border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'><span style='color: #9944FF'>You:</span><br/>now show me 3 of these verses that you found. For each of them tell me where it is from (book name, chapter, verse number) and the text of the verse.</div>
# {'role': 'user', 'content': 'now show me 3 of these verses that you found. For each of them tell me where it is from (book name, chapter, verse number) and the text of the verse.'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "Here are 3 verses containing the phrase \'ערום\':\\n\\n1.  Book: Genesis, Chapter: 3, Verse: 1.\\n   Text: {\\"book_id\\": 1, \\"book_name\\": \\"Genesis\\", \\"chapter\\": 3, \\"verse\\": 1}\\n\\n2.  Book: Deuteronomy, Chapter: 32, Verse: 17.\\n   Text: {\\"book_id\\": 5, \\"book_name\\": \\"Deuteronomy\\", \\"chapter\\": 32, \\"verse\\": 17}\\n\\n3.  Book: 1 Samuel, Chapter: 23, Verse: 22.\\n   Text: {\\"book_id\\": 9, \\"book_name\\": \\"1 Samuel\\", \\"chapter\\": 23, \\"verse\\": 22}\\n\\nAlso, the text of these verses is available to you."}}'}
# <div style='display: inline-block; border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'><span style='color: #2222FF'>Assistant:</span><br/>Here are 3 verses containing the phrase 'ערום':<br/><br/>1.  Book: Genesis, Chapter: 3, Verse: 1.<br/>   Text: {"book_id": 1, "book_name": "Genesis", "chapter": 3, "verse": 1}<br/><br/>2.  Book: Deuteronomy, Chapter: 32, Verse: 17.<br/>   Text: {"book_id": 5, "book_name": "Deuteronomy", "chapter": 32, "verse": 17}<br/><br/>3.  Book: 1 Samuel, Chapter: 23, Verse: 22.<br/>   Text: {"book_id": 9, "book_name": "1 Samuel", "chapter": 23, "verse": 22}<br/><br/>Also, the text of these verses is available to you.</div>
# <div style='display: inline-block; border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'><span style='color: #9944FF'>You:</span><br/>close. you showed me the references (book name, chapter, verse number) of 3 such verses that contain the phrase "ערום". Now please lookup each of these verses and show me the text of each verse</div>
# {'role': 'user', 'content': 'close. you showed me the references (book name, chapter, verse number) of 3 such verses that contain the phrase "ערום". Now please lookup each of these verses and show me the text of each verse'}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "ערום", "book": "Genesis", "chapter_num": 3, "verse_num": 1}}\n'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "error", "error_message": "We don\'t support text-version named \'ערום\'. Here are the supported version:\\n  Version: \'he.text_only\'. Description: Hebrew language, only letters.\\n  Version: \'he.masorah\'. Description: Hebrew language, traditional script version (full markings).\\n  Version: \'en.new.jps1917\'. Description: English language, JPS.\\n  Version: \'en.koren\'. Description: English language, Koren."}'}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "he.text_only", "book": "Genesis", "chapter_num": 3, "verse_num": 1}}\n'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "ok", "result": {"version": "he.text_only", "book": "genesis", "chapter_num": 3, "verse_num": 1, "text": "והנחש היה ערום מכל חית השדה אשר עשה יהוה אלהים ויאמר אל האשה אף כי אמר אלהים לא תאכלו מכל עץ הגן"}}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "והנחש היה ערום מכל חית השדה אשר עשה יהוה אלהים ויאמר אל האשה אף כי אמר אלהים לא תאכלו מכל עץ הגן"}}'}
# <div style='display: inline-block; border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'><span style='color: #2222FF'>Assistant:</span><br/>והנחש היה ערום מכל חית השדה אשר עשה יהוה אלהים ויאמר אל האשה אף כי אמר אלהים לא תאכלו מכל עץ הגן</div>
# <div style='display: inline-block; border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'><span style='color: #9944FF'>You:</span><br/>thank you :-)</div>
# {'role': 'user', 'content': 'thank you :-)'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "You\'re welcome."}}'}
# <div style='display: inline-block; border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'><span style='color: #2222FF'>Assistant:</span><br/>You're welcome.</div>
# <div style='display: inline-block; border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'><span style='color: #9944FF'>You:</span><br/>exit</div>
# <div style='display: inline-block; border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'><span style='color: #2222FF'>Assistant:</span><br/>Bye!</div>

# %% [markdown]
# ## Look at all the message "behind the scenes":

# %%
print("="*40)
for msg in agentUI.agent.messages:
    print(msg)
print("="*40)
# Out:
# ========================================
# {'role': 'system', 'content': 'You are a research assistant that always responds using a JSON object with fields "tool" and "arguments".\n\nTo respond normally to the user, use:\n{"tool": "respond_to_user", "arguments":{"text": "<text to show the user>"}}\n\nTo call a tool, use:\n{"tool": "<tool_name>", "arguments":{ ... }}\n\nAfter you call a tool, you will receive a message with role "user" containing a JSON object.\nThe tool message always includes "tool_name" and "status".\n\nIf "status" is "ok":\n- The message will include a "result" object.\n- Read "result.text".\n- Respond using "respond_to_user" and copy "result.text" exactly as-is.\n\nIf "status" is "error":\n- The message will include an "error_message".\n- If the error message is clear enough (e.g., if the user spelled a book name wrong and it is clear which book the user intended), you can call the tool again with the corrected arguments.\n- Otherwise, respond using "respond_to_user" and copy "error_message" exactly as-is (to let the user tell you what to do next).\n\nRules:\n- Never modify, translate, summarize, or explain text returned by the tool.\n- Never add commentary or extra text.\n- Never guess missing arguments.\n- Never correct user mistakes on the first attempt of a tool call.\n- Never retry a failed tool call with exactly the same arguments.\n\nAvailable toos:\n\nTo get the text of a specific biblical verse:\n{"tool": "lookup_verse", "arguments":{"version":"<version>", book:"<book>", chapter_num:<integer>, verse_num:<integer>}}\nWhen this tool call succeeds, contains the verse. Copy it exactly as-is and return to the user with "respond_to_user".\n\nTo search for all the verses that have a certain word or phrase:\n{"tool": "search_phrase", "arguments":{"phrase":"<phrase>"}}\nWhen this tool call succeeds, the result will be a dictionary with key "results", holding the list of all the occurrences of the phrase. Respond to the user, simply to indicate that the call succeeded, with "respond_to_user".\nThen be prepared to answer further questions about the results you got from the tool.\n\n'}
# {'role': 'user', 'content': 'find all the places that mention the word "ערום"'}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "ערום", "book": "הש Accountability", "chapter_num": 1, "verse_num": 1}}\n'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "error", "error_message": "We don\'t support book named \'הש accountability\'. Here are the supported books: genesis, exodus, leviticus, numbers, deuteronomy, isaiah, jeremiah"}'}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "ערום", "book": "leviticus", "chapter_num": 1, "verse_num": 1}}\n'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "error", "error_message": "We don\'t support text-version named \'ערום\'. Here are the supported version:\\n  Version: \'he.text_only\'. Description: Hebrew language, only letters.\\n  Version: \'he.masorah\'. Description: Hebrew language, traditional script version (full markings).\\n  Version: \'en.new.jps1917\'. Description: English language, JPS.\\n  Version: \'en.koren\'. Description: English language, Koren."}'}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "he.masorah", "book": "ערום", "chapter_num": 1, "verse_num": 1}}\n'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "error", "error_message": "We don\'t support book named \'ערום\'. Here are the supported books: genesis, exodus, leviticus, numbers, deuteronomy, isaiah, jeremiah"}'}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "he.masorah", "book": "ערום", "chapter_num": 1, "verse_num": 1}}\n'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "error", "error_message": "We don\'t support book named \'ערום\'. Here are the supported books: genesis, exodus, leviticus, numbers, deuteronomy, isaiah, jeremiah"}'}
# {'role': 'user', 'content': 'call the tool search_phrase with phrase "ערום"'}
# {'role': 'assistant', 'content': '{"tool": "search_phrase", "arguments": {"phrase": "ערום"}}\n'}
# {'role': 'user', 'content': '{"tool_name": "search_phrase", "status": "ok", "result": {"results": [{"book_id": 1, "book_name": "Genesis", "chapter": 3, "verse": 1, "text": "והנחש היה ערום מכל חית השדה אשר עשה יהוה אלהים ויאמר אל־האשה אף כי־אמר אלהים לא תאכלו מכל עץ הגן׃"}, {"book_id": 5, "book_name": "Deuteronomy", "chapter": 32, "verse": 17, "text": "יזבחו לשדים לא אלה אלהים לא ידעום חדשים מקרב באו לא שערום אבתיכם׃"}, {"book_id": 9, "book_name": "1 Samuel", "chapter": 23, "verse": 22, "text": "לכו־נא הכינו עוד ודעו וראו את־מקומו אשר תהיה רגלו מי ראהו שם כי אמר אלי ערום יערם הוא׃"}, {"book_id": 18, "book_name": "Job", "chapter": 24, "verse": 7, "text": "ערום ילינו מבלי לבוש ואין כסות בקרה׃"}, {"book_id": 18, "book_name": "Job", "chapter": 24, "verse": 10, "text": "ערום הלכו בלי לבוש ורעבים נשאו עמר׃"}, {"book_id": 18, "book_name": "Job", "chapter": 26, "verse": 6, "text": "ערום שאול נגדו ואין כסות לאבדון׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 12, "verse": 16, "text": "אויל ביום יודע כעסו וכסה קלון ערום׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 12, "verse": 23, "text": "אדם ערום כסה דעת ולב כסילים יקרא אולת׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 13, "verse": 16, "text": "כל־ערום יעשה בדעת וכסיל יפרש אולת׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 14, "verse": 8, "text": "חכמת ערום הבין דרכו ואולת כסילים מרמה׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 14, "verse": 15, "text": "פתי יאמין לכל־דבר וערום יבין לאשרו׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 22, "verse": 3, "text": "ערום ׀ ראה רעה [ויסתר כ] (ונסתר ק) ופתיים עברו ונענשו׃"}, {"book_id": 20, "book_name": "Proverbs", "chapter": 27, "verse": 12, "text": "ערום ראה רעה נסתר פתאים עברו נענשו׃"}, {"book_id": 21, "book_name": "Ecclesiastes", "chapter": 5, "verse": 14, "text": "כאשר יצא מבטן אמו ערום ישוב ללכת כשבא ומאומה לא־ישא בעמלו שילך בידו׃"}, {"book_id": 23, "book_name": "Isaiah", "chapter": 20, "verse": 2, "text": "בעת ההיא דבר יהוה ביד ישעיהו בן־אמוץ לאמר לך ופתחת השק מעל מתניך ונעלך תחלץ מעל רגליך ויעש כן הלך ערום ויחף׃    ס"}, {"book_id": 23, "book_name": "Isaiah", "chapter": 20, "verse": 3, "text": "ויאמר יהוה כאשר הלך עבדי ישעיהו ערום ויחף שלש שנים אות ומופת על־מצרים ועל־כוש׃"}, {"book_id": 23, "book_name": "Isaiah", "chapter": 20, "verse": 4, "text": "כן ינהג מלך־אשור את־שבי מצרים ואת־גלות כוש נערים וזקנים ערום ויחף וחשופי שת ערות מצרים׃"}, {"book_id": 26, "book_name": "Ezekiel", "chapter": 18, "verse": 16, "text": "ואיש לא הונה חבל לא חבל וגזלה לא גזל לחמו לרעב נתן וערום כסה־בגד׃"}, {"book_id": 30, "book_name": "Amos", "chapter": 2, "verse": 16, "text": "ואמיץ לבו בגבורים ערום ינוס ביום־ההוא נאם־יהוה׃  פ"}, {"book_id": 33, "book_name": "Micah", "chapter": 1, "verse": 8, "text": "על־זאת אספדה ואילילה אילכה [שילל כ] (שולל ק) וערום אעשה מספד כתנים ואבל כבנות יענה׃"}]}}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "ערום"}}'}
# ========================================

# %% [markdown]
# ## Try with different models or training checkpoints

# %%
# I serve the models via the ollama interface. Check which models are available:
import ollama
ollama.list().models
# Out:
# [Model(model='gemma3:1b-ft9-650', modified_at=datetime.datetime(2026, 1, 28, 9, 17, 20, 621636, tzinfo=TzInfo(-18000)), digest='c5a1be2c32546bb87caedb2bf083dc2cf574f767233460d3cb0dd6d4f6e9e866', size=2015833891, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='999.89M', quantization_level='F16')),
#  Model(model='gemma3:1b-ft9-350', modified_at=datetime.datetime(2026, 1, 28, 9, 16, 5, 457480, tzinfo=TzInfo(-18000)), digest='8d25ff0f607b75234689b0a8a1d8104ab6895a444845c699068b889785fdf89c', size=2015833891, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='999.89M', quantization_level='F16')),
#  Model(model='gemma3:1b-ft3-50', modified_at=datetime.datetime(2026, 1, 23, 13, 54, 9, 433956, tzinfo=TzInfo(-18000)), digest='9daf2271960acc2503ed4f895bbefdf85ea4b0d77e18348fedf6be476d8bfbab', size=2015833891, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='999.89M', quantization_level='F16')),
#  Model(model='gemma3:1b-ft3-200', modified_at=datetime.datetime(2026, 1, 23, 13, 48, 22, 338494, tzinfo=TzInfo(-18000)), digest='19a72e403cba4e546672312fe3add372f266bbcfd205e4d9f76b30d9e9a97ca8', size=2015833891, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='999.89M', quantization_level='F16')),
#  Model(model='gemma3:1b-ft3', modified_at=datetime.datetime(2026, 1, 23, 13, 39, 57, 531804, tzinfo=TzInfo(-18000)), digest='f29938c31eef2f0966c7148ba9630307fa0381f21d5fbcfacbb43ba872d3840e', size=2015833891, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='999.89M', quantization_level='F16')),
#  Model(model='gemma3:1b-ft2', modified_at=datetime.datetime(2026, 1, 23, 11, 51, 6, 306399, tzinfo=TzInfo(-18000)), digest='252321fba99d14a9cba449fa8f045c92e97bdec3fadcbfa9ab446766caca55a8', size=2015833891, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='999.89M', quantization_level='F16')),
#  Model(model='gemma3:1b-ft1', modified_at=datetime.datetime(2026, 1, 16, 10, 38, 25, 375681, tzinfo=TzInfo(-18000)), digest='f246014b90b8cb36ca293a97c7b5c5ce2e9cfa4790050d6a659c02401dca8c9c', size=2015833891, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='999.89M', quantization_level='F16')),
#  Model(model='google/gemma-3-1b-it-ft1:latest', modified_at=datetime.datetime(2026, 1, 16, 10, 8, 13, 449228, tzinfo=TzInfo(-18000)), digest='b615ad8f3a73023d47771e856d21f4069d053d3e745b000a5752f5b858b0586d', size=2015825284, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='999.89M', quantization_level='F16')),
#  Model(model='gemma3:4b', modified_at=datetime.datetime(2026, 1, 14, 9, 23, 35, 705701, tzinfo=TzInfo(-18000)), digest='a2af6cc3eb7fa8be8504abaf9b04e88f17a119ec3f04a3addf55f92841195f5a', size=3338801804, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='4.3B', quantization_level='Q4_K_M')),
#  Model(model='llama3.2:3b', modified_at=datetime.datetime(2026, 1, 7, 13, 40, 29, 314297, tzinfo=TzInfo(-18000)), digest='a80c4f17acd55265feec403c7aef86be0c25983ab279d83f3bcd3abbcb5b8b72', size=2019393189, details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='3.2B', quantization_level='Q4_K_M')),
#  Model(model='llama3.2:1b', modified_at=datetime.datetime(2026, 1, 7, 13, 39, 39, 839186, tzinfo=TzInfo(-18000)), digest='baf6a787fdffd633537aa2eb51cfd54cb93ff08e28040095462bb63daf552878', size=1321098329, details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='1.2B', quantization_level='Q8_0')),
#  Model(model='gemma3:1b', modified_at=datetime.datetime(2025, 12, 15, 16, 18, 47, 663104, tzinfo=TzInfo(-18000)), digest='8648f39daa8fbf5b18c7b4e6a8fb4990c692751d49917417b8842ca5758e7ffc', size=815319791, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='999.89M', quantization_level='Q4_K_M')),
#  Model(model='mistral:latest', modified_at=datetime.datetime(2025, 12, 9, 19, 37, 27, 232056, tzinfo=TzInfo(-18000)), digest='6577803aa9a036369e481d648a2baebb381ebc6e897f2bb9a766a2aa7bfbc1cf', size=4372824384, details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='7.2B', quantization_level='Q4_K_M'))]

# %%
agentUI = bibleAssistant.agent.AgentUI("gemma3:1b-ft3-200", verbose=False)
agentUI.start_session()
# Out:
# Agent ready to talk. Type 'exit' to quit.
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# Hi</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# We don't support text-version named '1033'. Here are the supported version:
#   Version: 'he.text_only'. Description: Hebrew language, only letters.
#   Version: 'he.masorah'. Description: Hebrew language, traditional script version (full markings).
#   Version: 'en.new.jps1917'. Description: English language, JPS.
#   Version: 'en.koren'. Description: English language, Koren.</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# please give me exodus 1:1 in a hebrew version ("he.text_only")</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# ואלה שמות בני ישראל הבאים מצרימה את יעקב איש וביתו באו</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# great. now give me the same verse from version 'he.masorah'</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# וְאֵ֗לֶּה שְׁמוֹת֙ בְּנֵ֣י יִשְׂרָאֵ֔ל הַבָּאִ֖ים מִצְרָ֑יְמָה אֵ֣ת יַעֲקֹ֔ב אִ֥ישׁ וּבֵית֖וֹ בָּֽאוּ׃</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# and from version 'en.koren'</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# NOW these are the names of the children of Yisra᾽el who came into Miżrayim, with Ya῾aqov; every man came with his household.</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# give me gensis 5:10 from 'en.koren'</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# and Enosh lived after he begot Qenan eight hundred and fifteen years, and begot sons and daughters:</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# and from version 'he.mesorah'</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# We don't support text-version named 'he.mesorah'. Here are the supported version:
#   Version: 'he.text_only'. Description: Hebrew language, only letters.
#   Version: 'he.masorah'. Description: Hebrew language, traditional script version (full markings).
#   Version: 'en.new.jps1917'. Description: English language, JPS.
#   Version: 'en.koren'. Description: English language, Koren.</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# sorry, i misspelled 'he.masorah'</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# Sorry, I misspelled 'he.masorah'. Here are the supported version:
#   Version: 'he.text_only'. Description: Hebrew language, only letters.
#   Version: 'he.masorah'. Description: Hebrew language, traditional script version (full markings).
#   Version: 'en.new.jps1917'. Description: English language, JPS.
#   Version: 'en.koren'. Description: English language, Koren.</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# give me genesis 5:10 from 'he.mesorah'</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# We don't support text-version named 'he.mesorah'. Here are the supported version:
#   Version: 'he.text_only'. Description: Hebrew language, only letters.
#   Version: 'he.masorah'. Description: Hebrew language, traditional script version (full markings).
#   Version: 'en.new.jps1917'. Description: English language, JPS.
#   Version: 'en.koren'. Description: English language, Koren.</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# sorry, I meant 'he.masorah'</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# Sorry, I meant 'he.masorah' again. Here are the supported version:
#   Version: 'he.text_only'. Description: Hebrew language, only letters.
#   Version: 'he.masorah'. Description: Hebrew language, traditional script version (full markings).
#   Version: 'en.new.jps1917'. Description: English language, JPS.
#   Version: 'en.koren'. Description: English language, Koren.</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'>You:
# exit</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'>Assistant:
# Bye!</div>

# %%
agentUI = bibleAssistant.agent.AgentUI("gemma3:1b-ft3-200", verbose=False)
agentUI.start_session()
# Out:
# Agent ready to talk. Type 'exit' to quit.
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'><span style='background-color: #9944FF'>You:</span><br/>hello</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'><span style='background-color: #2222FF'>Assistant:</span><br/>hello</div>
# <div style='border:3px solid #9944FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 5px'><span style='background-color: #9944FF'>You:</span><br/>exit</div>
# <div style='border:3px solid #2222FF; padding:10px; margin-bottom:5px; border-radius: 5px; margin-left: 50px'><span style='background-color: #2222FF'>Assistant:</span><br/>Bye!</div>

# %%
print("="*40)
for msg in agentUI.agent.messages:
    print(msg)
print("="*40)
# Out:
# ========================================
# {'role': 'system', 'content': 'You are a research assistant that always responds using a JSON object with fields "tool" and "arguments".\n\nTo respond normally to the user, use:\n{"tool": "respond_to_user", "arguments":{"text": "<text to show the user>"}}\n\nTo call a tool, use:\n{"tool": "<tool_name>", "arguments":{ ... }}\n\nAfter you call a tool, you will receive a message with role "user" containing a JSON object.\nThe tool message always includes "tool_name" and "status".\n\nIf "status" is "ok":\n- The message will include a "result" object.\n- Read "result.text".\n- Respond using "respond_to_user" and copy "result.text" exactly as-is.\n\nIf "status" is "error":\n- The message will include an "error_message".\n- If the error message is clear enough (e.g., if the user spelled a book name wrong and it is clear which book the user intended), you can call the tool again with the corrected arguments.\n- Otherwise, respond using "respond_to_user" and copy "error_message" exactly as-is (to let the user tell you what to do next).\n\nRules:\n- Never modify, translate, summarize, or explain text returned by the tool.\n- Never add commentary or extra text.\n- Never guess missing arguments.\n- Never correct user mistakes on the first attempt of a tool call.\n- Never retry a failed tool call with exactly the same arguments.\n\nAvailable tool:\n\nTo get the text of a specific biblical verse:\n{"tool": "lookup_verse", "arguments":{"version":"<version>", book:"<book>", chapter_num:<integer>, verse_num:<integer>}}\nWhen this tool call succeeds, contains the verse. Copy it exactly as-is and return to the user with "respond_to_user".\n\n'}
# {'role': 'user', 'content': 'Hi'}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "1033", "book": "Genesis", "chapter_num": 1, "verse_num": 1}}'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "error", "error_message": "We don\'t support text-version named \'1033\'. Here are the supported version:\\n  Version: \'he.text_only\'. Description: Hebrew language, only letters.\\n  Version: \'he.masorah\'. Description: Hebrew language, traditional script version (full markings).\\n  Version: \'en.new.jps1917\'. Description: English language, JPS.\\n  Version: \'en.koren\'. Description: English language, Koren."}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "We don\'t support text-version named \'1033\'. Here are the supported version:\\n  Version: \'he.text_only\'. Description: Hebrew language, only letters.\\n  Version: \'he.masorah\'. Description: Hebrew language, traditional script version (full markings).\\n  Version: \'en.new.jps1917\'. Description: English language, JPS.\\n  Version: \'en.koren\'. Description: English language, Koren."}}'}
# {'role': 'user', 'content': 'please give me exodus 1:1 in a hebrew version ("he.text_only")'}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "he.text_only", "book": "exodus", "chapter_num": 1, "verse_num": 1}}'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "ok", "result": {"version": "he.text_only", "book": "exodus", "chapter_num": 1, "verse_num": 1, "text": "ואלה שמות בני ישראל הבאים מצרימה את יעקב איש וביתו באו"}}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "ואלה שמות בני ישראל הבאים מצרימה את יעקב איש וביתו באו"}}'}
# {'role': 'user', 'content': "great. now give me the same verse from version 'he.masorah'"}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "he.masorah", "book": "exodus", "chapter_num": 1, "verse_num": 1}}'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "ok", "result": {"version": "he.masorah", "book": "exodus", "chapter_num": 1, "verse_num": 1, "text": "וְאֵ֗לֶּה שְׁמוֹת֙ בְּנֵ֣י יִשְׂרָאֵ֔ל הַבָּאִ֖ים מִצְרָ֑יְמָה אֵ֣ת יַעֲקֹ֔ב אִ֥ישׁ וּבֵית֖וֹ בָּֽאוּ׃"}}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "וְאֵ֗לֶּה שְׁמוֹת֙ בְּנֵ֣י יִשְׂרָאֵ֔ל הַבָּאִ֖ים מִצְרָ֑יְמָה אֵ֣ת יַעֲקֹ֔ב אִ֥ישׁ וּבֵית֖וֹ בָּֽאוּ׃"}}'}
# {'role': 'user', 'content': "and from version 'en.koren'"}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "en.koren", "book": "exodus", "chapter_num": 1, "verse_num": 1}}'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "ok", "result": {"version": "en.koren", "book": "exodus", "chapter_num": 1, "verse_num": 1, "text": "NOW these are the names of the children of Yisra᾽el who came into Miżrayim, with Ya῾aqov; every man came with his household."}}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "NOW these are the names of the children of Yisra᾽el who came into Miżrayim, with Ya῾aqov; every man came with his household."}}'}
# {'role': 'user', 'content': "give me gensis 5:10 from 'en.koren'"}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "en.koren", "book": "genesis", "chapter_num": 5, "verse_num": 10}}'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "ok", "result": {"version": "en.koren", "book": "genesis", "chapter_num": 5, "verse_num": 10, "text": "and Enosh lived after he begot Qenan eight hundred and fifteen years, and begot sons and daughters:"}}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "and Enosh lived after he begot Qenan eight hundred and fifteen years, and begot sons and daughters:"}}'}
# {'role': 'user', 'content': "and from version 'he.mesorah'"}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "he.mesorah", "book": "exodus", "chapter_num": 1, "verse_num": 1}}'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "error", "error_message": "We don\'t support text-version named \'he.mesorah\'. Here are the supported version:\\n  Version: \'he.text_only\'. Description: Hebrew language, only letters.\\n  Version: \'he.masorah\'. Description: Hebrew language, traditional script version (full markings).\\n  Version: \'en.new.jps1917\'. Description: English language, JPS.\\n  Version: \'en.koren\'. Description: English language, Koren."}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "We don\'t support text-version named \'he.mesorah\'. Here are the supported version:\\n  Version: \'he.text_only\'. Description: Hebrew language, only letters.\\n  Version: \'he.masorah\'. Description: Hebrew language, traditional script version (full markings).\\n  Version: \'en.new.jps1917\'. Description: English language, JPS.\\n  Version: \'en.koren\'. Description: English language, Koren."}}'}
# {'role': 'user', 'content': "sorry, i misspelled 'he.masorah'"}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "Sorry, I misspelled \'he.masorah\'. Here are the supported version:\\n  Version: \'he.text_only\'. Description: Hebrew language, only letters.\\n  Version: \'he.masorah\'. Description: Hebrew language, traditional script version (full markings).\\n  Version: \'en.new.jps1917\'. Description: English language, JPS.\\n  Version: \'en.koren\'. Description: English language, Koren."}}'}
# {'role': 'user', 'content': "give me genesis 5:10 from 'he.mesorah'"}
# {'role': 'assistant', 'content': '{"tool": "lookup_verse", "arguments": {"version": "he.mesorah", "book": "genesis", "chapter_num": 5, "verse_num": 10}}'}
# {'role': 'user', 'content': '{"tool_name": "lookup_verse", "status": "error", "error_message": "We don\'t support text-version named \'he.mesorah\'. Here are the supported version:\\n  Version: \'he.text_only\'. Description: Hebrew language, only letters.\\n  Version: \'he.masorah\'. Description: Hebrew language, traditional script version (full markings).\\n  Version: \'en.new.jps1917\'. Description: English language, JPS.\\n  Version: \'en.koren\'. Description: English language, Koren."}'}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "We don\'t support text-version named \'he.mesorah\'. Here are the supported version:\\n  Version: \'he.text_only\'. Description: Hebrew language, only letters.\\n  Version: \'he.masorah\'. Description: Hebrew language, traditional script version (full markings).\\n  Version: \'en.new.jps1917\'. Description: English language, JPS.\\n  Version: \'en.koren\'. Description: English language, Koren."}}'}
# {'role': 'user', 'content': "sorry, I meant 'he.masorah'"}
# {'role': 'assistant', 'content': '{"tool": "respond_to_user", "arguments": {"text": "Sorry, I meant \'he.masorah\' again. Here are the supported version:\\n  Version: \'he.text_only\'. Description: Hebrew language, only letters.\\n  Version: \'he.masorah\'. Description: Hebrew language, traditional script version (full markings).\\n  Version: \'en.new.jps1917\'. Description: English language, JPS.\\n  Version: \'en.koren\'. Description: English language, Koren."}}'}
# ========================================

# %% [markdown]
# ## Review, assess, improve
#
# After interacting with the trained agent, reflect:
# - what can it do well?
# - where is it still screwing up?
# - How can I improve it?
